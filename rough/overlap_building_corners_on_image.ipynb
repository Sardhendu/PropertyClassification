# %%
from __future__ import division, print_function, absolute_import

import cv2
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt

import shapely.geometry as geom
import geopandas as gpd

from latlon_to_pixelXY import lonlatToPixel, get_image_corner_latlon_and_pxls_vals
import utils as utl

zoom = 19
lat, lon = 41.845989, -87.717689
static_image_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/staticmap0.png'
output_manual_segment = '/Users/sam/All-Program/App-DataSet/HouseClassification/staticmap0_out.png'

# zoom = 19
# lat, lon = 41.845824,-87.716752
# static_image_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/staticmap1.png'
# output_manual_segment = '/Users/sam/All-Program/App-DataSet/HouseClassification/staticmap1_out.png'


property_parcel_shape_file_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/shape_files/sample/'

# %matplotlib inline

# %% [markdown]
# ## Get static image corners in terms of Lat and Lon
# ---------

# %%
pxls_corner_arr, lonlat_corner_arr = get_image_corner_latlon_and_pxls_vals(lat, lon, zoom)
tl_ll, tr_ll, bl_ll, br_ll = lonlat_corner_arr
tl_pxl, tr_pxl, bl_pxl, br_pxl = pxls_corner_arr
image_corner_polygon = geom.Polygon(np.array([tl_ll, tr_ll, br_ll, bl_ll, tl_ll]))   # The polygon should start from a point and end at the same point
print (image_corner_polygon)
# Out:
# POLYGON ((-87.71822544180296 41.84638861611691, -87.717152558197 41.84638861611691, -87.717152558197 41.84558938138701, -87.71822544180296 41.84558938138701, -87.71822544180296 41.84638861611691))

# %%
# Check if the center of the Polygon is the same as the provided Lat Lon
np.array(image_corner_polygon.centroid.coords)[0]
# Out:
# array([-87.717689,  41.845989])

# %% [markdown]
# ## Fetch all the parcels that lie inside the Image extracted
# --------

# %% [markdown]
# #### Step1: Get the Scooped lat lon list

# %%
## Get the extra scoop's: We dont want to search for all the property, but the property that are neat the vicinity of the extracted image
scoop_lon, scooop_lat = utl.getscoopLonLat(lonIN=lon, latIN=lat, decimalPlaces=1000)
scoop_latlon = utl.getscoopSearchItems(scoopLon=scoop_lon, scoopLat=scooop_lat, decimalPlaces=1000)
print (scoop_latlon)
# Out:
# [['-87.718' '41.844']
#  ['-87.718' '41.845']
#  ['-87.718' '41.846']
#  ['-87.717' '41.844']
#  ['-87.717' '41.845']
#  ['-87.717' '41.846']
#  ['-87.716' '41.844']
#  ['-87.716' '41.845']
#  ['-87.716' '41.846']]

# %% [markdown]
# #### Step2: Get all the property in the scoop

# %%
def get_search_polygons(df, scoop_latlon):
    query = ''
    for num, (i, j) in enumerate(scoop_latlon):
        query += '((lon_scoop=="%s") & (lat_scoop=="%s"))'%(str(i),(j))
        if num!=(len(scoop_latlon)-1):
            query += ' | '
    return df[df.eval(query)]
#     query = 'building==%s'%('"yes"')
#     break
property_parcel = gpd.read_file(property_parcel_shape_file_path)
search_polygons = get_search_polygons(property_parcel, scoop_latlon)
print (search_polygons.shape)
search_polygons.head()
# Out:
# (78, 13)
#        parcel_id house_numb             street_add street_nam street_pre  \
# 0  way/163767492       2451  South Lawndale Avenue   Lawndale      South
# 2  way/163767501       2452  South Lawndale Avenue   Lawndale      South
# 3  way/163767522       2454   South Millard Avenue    Millard      South
# 4  way/163767530       2455  South Lawndale Avenue   Lawndale      South
# 5  way/163767543       2456  South Lawndale Avenue   Lawndale      South
#
#   building building_l shape_type lat_scoop lon_scoop         lat_center  \
# 0      yes          2    Polygon    41.846   -87.717  41.84650960512757
# 2      yes          3    Polygon    41.846   -87.717  41.84648109184263
# 3      yes          2    Polygon    41.846   -87.716   41.8464311907146
# 4      yes          2    Polygon    41.846   -87.717  41.84642069292985
# 5      yes          2    Polygon    41.846   -87.717  41.84636960337455
#
#            lon_center                                           geometry
# 0  -87.71703814927186  POLYGON ((-87.7171232 41.8464752, -87.71712309...
# 2  -87.71759474590094  POLYGON ((-87.7175713 41.8464392, -87.7175877 ...
# 3  -87.71636055067256  POLYGON ((-87.71636599999999 41.846397, -87.71...
# 4  -87.71702471950471  POLYGON ((-87.71712220000001 41.8463833, -87.7...
# 5  -87.71757841554287  POLYGON ((-87.7174859 41.846344, -87.7176695 4...

# %% [markdown]
# #### Out of the scooped Properties, Select only the properties that have the center point inside the image polygon

# %%
def get_parcels_inside_image(df):
    list_parcel_ids = []
    for parcel_id, lon_cent, lat_cent in np.array(df[['parcel_id','lon_center', 'lat_center']]):
        lon_cent = float(lon_cent) 
        lat_cent = float(lat_cent)
        is_contains = image_corner_polygon.contains(geom.Point([lon_cent, lat_cent]))
        if is_contains:
#             print (parcel_id)
            list_parcel_ids.append(parcel_id)
            
    if len(list_parcel_ids) > 0:
        return df[df['parcel_id'].isin(list_parcel_ids)]
    
parcels_in_image = get_parcels_inside_image(search_polygons)
print (parcels_in_image.shape)
parcels_in_image.head()
# Out:
# (8, 13)
#         parcel_id house_numb             street_add street_nam street_pre  \
# 5   way/163767543       2456  South Lawndale Avenue   Lawndale      South
# 6   way/163767553       2458  South Lawndale Avenue   Lawndale      South
# 9   way/163767576       2500  South Lawndale Avenue   Lawndale      South
# 14  way/163767641       2506  South Lawndale Avenue   Lawndale      South
# 16  way/163767657       2508  South Lawndale Avenue   Lawndale      South
#
#    building building_l shape_type lat_scoop lon_scoop         lat_center  \
# 5       yes          2    Polygon    41.846   -87.717  41.84636960337455
# 6       yes          2    Polygon    41.846   -87.717  41.84631333683656
# 9       yes          2    Polygon    41.846   -87.717   41.8460560082056
# 14      yes          2    Polygon    41.845   -87.717  41.84593256973168
# 16      yes          1    Polygon    41.845   -87.717    41.845863773618
#
#             lon_center                                           geometry
# 5   -87.71757841554287  POLYGON ((-87.7174859 41.846344, -87.7176695 4...
# 6   -87.71757668909439  POLYGON ((-87.7174859 41.846344, -87.7174828 4...
# 9   -87.71756770040085  POLYGON ((-87.71754610000001 41.8459958, -87.7...
# 14  -87.71756505789992  POLYGON ((-87.71766820000001 41.8459018, -87.7...
# 16  -87.71754821084377  POLYGON ((-87.7176102 41.845826, -87.7176303 4...

# %%
# print (bl_pxl)
# for pid, geomt in np.array(parcels_in_image[['parcel_id', 'geometry']]):
#     print (pid)
#     arr = geomt.exterior.coords.xy
#     llon, llat = arr[0], arr[1]
#     arr_in = [(i, j) for i, j in zip(llat, llon)]
    
#     for latt, lonn in arr_in:
#         mx, my = obj_ll_to_pxl.lonlat_to_meters(lonn,latt)
#         px, py = obj_ll_to_pxl.meters_to_pixels(mx, my)
#         print (px, py)
#         img_x, img_y = obj_ll_to_pxl.convert_map_pxl_to_img_pxl(bl_pxl, [px, py])
#         print (img_x, img_y)
#     print ('')

# %% [markdown]
# ## PLOT the parcel boundaries on top of the image
# -------------

# %% [markdown]
# #### Convert parcel Lat Lon to pixel places in Image

# %%
img_orig = cv2.imread(static_image_path)

img = img_orig.copy()
# output = img_orig.copy()

# def draw_polygons(img, xy_arr):
#     alpha = 0.5
#     xy_arr = np.array(xy_arr, np.int32)
# #     xy_arr = xy_arr.reshape(-1,1,2) 
#     img = cv2.polylines(img,[xy_arr],True,(0,0,255))
#     img = cv2.addWeighted(img, alpha, output, 1 - alpha, 0, output)
#     return output

def draw_polygons(img, xy_arr):
    alpha = 0.5
    xy_arr = np.array(xy_arr, np.int32)
    layer = img.copy()
    output = img.copy()
    layer = cv2.fillPoly(layer, [xy_arr], (0,0,255))#, offset=0.4)
    output = cv2.addWeighted(layer, alpha, output, 1 - alpha, 0, output)
    return output

a = []
obj_ll_to_pxl = lonlatToPixel(zoom=19)
parcel_pixel_vals = []
for parcel_id, polygon_geom in np.array(parcels_in_image[['parcel_id', 'geometry']]):
    points_tuple = polygon_geom.exterior.coords.xy
    lon_arr, lat_arr = list(points_tuple[0]), list(points_tuple[1])
    each_parcel_xy_arr = []
    for lon, lat in zip(lon_arr, lat_arr):
        mx, my = obj_ll_to_pxl.lonlat_to_meters(lon,lat)
        px, py = obj_ll_to_pxl.meters_to_pixels(mx, my)
#         print (tl_pxl)
#         print (px, py)
        img_x, img_y = obj_ll_to_pxl.convert_map_pxl_to_img_pxl(tl_pxl, [px, py])
        each_parcel_xy_arr.append([int(np.round(img_x)), int(np.round(img_y))])
    img = draw_polygons(img, xy_arr=each_parcel_xy_arr)
# Out:
# The new pixel value is not bounded by the images shape
# The new pixel value is not bounded by the images shape
# The new pixel value is not bounded by the images shape
# The new pixel value is not bounded by the images shape
# The new pixel value is not bounded by the images shape

# %%
cv2.imwrite(output_manual_segment, img)
# Out:
# True

# %% [markdown]
# # ROUGH:
# -------------

# %%
property_parcel[((property_parcel['lon_scoop']=='-87.717') & (property_parcel['lat_scoop']=='41.846')) | 
                ((property_parcel['lon_scoop']=='-87.716') & (property_parcel['lat_scoop']=='41.846'))]  # 41.846	-87.717
# Out:
#         parcel_id house_numb             street_add street_nam street_pre  \
# 0   way/163767492       2451  South Lawndale Avenue   Lawndale      South
# 2   way/163767501       2452  South Lawndale Avenue   Lawndale      South
# 3   way/163767522       2454   South Millard Avenue    Millard      South
# 4   way/163767530       2455  South Lawndale Avenue   Lawndale      South
# 5   way/163767543       2456  South Lawndale Avenue   Lawndale      South
# 6   way/163767553       2458  South Lawndale Avenue   Lawndale      South
# 7   way/163767565       2459  South Lawndale Avenue   Lawndale      South
# 9   way/163767576       2500  South Lawndale Avenue   Lawndale      South
# 10  way/163767578       2500   South Millard Avenue    Millard      South
# 67  way/163769422  3651-3655       West 25th Street       25th       West
# 68  way/163770241  3651-3655       West 25th Street       25th       West
# 79  way/163771150  3651-3655       West 25th Street       25th       West
# 92  way/405330603  3651-3655       West 25th Street       25th       West
#
#    building building_l shape_type lat_scoop lon_scoop         lat_center  \
# 0       yes          2    Polygon    41.846   -87.717  41.84650960512757
# 2       yes          3    Polygon    41.846   -87.717  41.84648109184263
# 3       yes          2    Polygon    41.846   -87.716   41.8464311907146
# 4       yes          2    Polygon    41.846   -87.717  41.84642069292985
# 5       yes          2    Polygon    41.846   -87.717  41.84636960337455
# 6       yes          2    Polygon    41.846   -87.717  41.84631333683656
# 7       yes          2    Polygon    41.846   -87.716  41.84632306647141
# 9       yes          2    Polygon    41.846   -87.717   41.8460560082056
# 10      yes          3    Polygon    41.846   -87.716   41.8460737203175
# 67      yes          3    Polygon    41.846   -87.716  41.84606098862837
# 68      yes          3    Polygon    41.846   -87.716  41.84632910896719
# 79      yes          3    Polygon    41.846   -87.716  41.84643145315182
# 92      yes          3    Polygon    41.846   -87.716  41.84633571792221
#
#             lon_center                                           geometry
# 0   -87.71703814927186  POLYGON ((-87.7171232 41.8464752, -87.71712309...
# 2   -87.71759474590094  POLYGON ((-87.7175713 41.8464392, -87.7175877 ...
# 3   -87.71636055067256  POLYGON ((-87.71636599999999 41.846397, -87.71...
# 4   -87.71702471950471  POLYGON ((-87.71712220000001 41.8463833, -87.7...
# 5   -87.71757841554287  POLYGON ((-87.7174859 41.846344, -87.7176695 4...
# 6   -87.71757668909439  POLYGON ((-87.7174859 41.846344, -87.7174828 4...
# 7   -87.71699989606041  POLYGON ((-87.7171195 41.8462831, -87.7171304 ...
# 9   -87.71756770040085  POLYGON ((-87.71754610000001 41.8459958, -87.7...
# 10  -87.71641003797632  POLYGON ((-87.7166117 41.8460361, -87.7166129 ...
# 67  -87.71692200184826  POLYGON ((-87.7171037 41.8460168, -87.71710659...
# 68  -87.71674652521912  POLYGON ((-87.7167836 41.8462881, -87.71678470...
# 79  -87.71675425348378  POLYGON ((-87.71679349999999 41.8464034, -87.7...
# 92  -87.71640598445104  POLYGON ((-87.716632 41.8463713, -87.716185999...

# %%
# Out:
# (78, 13)
#        parcel_id house_numb             street_add street_nam street_pre  \
# 0  way/163767492       2451  South Lawndale Avenue   Lawndale      South
# 2  way/163767501       2452  South Lawndale Avenue   Lawndale      South
# 3  way/163767522       2454   South Millard Avenue    Millard      South
# 4  way/163767530       2455  South Lawndale Avenue   Lawndale      South
# 5  way/163767543       2456  South Lawndale Avenue   Lawndale      South
#
#   building building_l shape_type lat_scoop lon_scoop         lat_center  \
# 0      yes          2    Polygon    41.846   -87.717  41.84650960512757
# 2      yes          3    Polygon    41.846   -87.717  41.84648109184263
# 3      yes          2    Polygon    41.846   -87.716   41.8464311907146
# 4      yes          2    Polygon    41.846   -87.717  41.84642069292985
# 5      yes          2    Polygon    41.846   -87.717  41.84636960337455
#
#            lon_center                                           geometry
# 0  -87.71703814927186  POLYGON ((-87.7171232 41.8464752, -87.71712309...
# 2  -87.71759474590094  POLYGON ((-87.7175713 41.8464392, -87.7175877 ...
# 3  -87.71636055067256  POLYGON ((-87.71636599999999 41.846397, -87.71...
# 4  -87.71702471950471  POLYGON ((-87.71712220000001 41.8463833, -87.7...
# 5  -87.71757841554287  POLYGON ((-87.7174859 41.846344, -87.7176695 4...

# %%
property_parcel[property_parcel.eval(query)]
# Out:
#         parcel_id house_numb             street_add street_nam street_pre  \
# 0   way/163767492       2451  South Lawndale Avenue   Lawndale      South
# 2   way/163767501       2452  South Lawndale Avenue   Lawndale      South
# 3   way/163767522       2454   South Millard Avenue    Millard      South
# 4   way/163767530       2455  South Lawndale Avenue   Lawndale      South
# 5   way/163767543       2456  South Lawndale Avenue   Lawndale      South
# 6   way/163767553       2458  South Lawndale Avenue   Lawndale      South
# 7   way/163767565       2459  South Lawndale Avenue   Lawndale      South
# 9   way/163767576       2500  South Lawndale Avenue   Lawndale      South
# 10  way/163767578       2500   South Millard Avenue    Millard      South
# 12  way/163767613       2504   South Millard Avenue    Millard      South
# 13  way/163767626       2505  South Lawndale Avenue   Lawndale      South
# 14  way/163767641       2506  South Lawndale Avenue   Lawndale      South
# 15  way/163767649       2507  South Lawndale Avenue   Lawndale      South
# 16  way/163767657       2508  South Lawndale Avenue   Lawndale      South
# 17  way/163767658       2508   South Millard Avenue    Millard      South
# 19  way/163767682       2510  South Lawndale Avenue   Lawndale      South
# 20  way/163767683       2510   South Millard Avenue    Millard      South
# 21  way/163767698       2511  South Lawndale Avenue   Lawndale      South
# 23  way/163767727       2514  South Lawndale Avenue   Lawndale      South
# 24  way/163767728       2514   South Millard Avenue    Millard      South
# 25  way/163767737       2515  South Lawndale Avenue   Lawndale      South
# 27  way/163767756       2517  South Lawndale Avenue   Lawndale      South
# 29  way/163767770       2518   South Millard Avenue    Millard      South
# 30  way/163767778       2519  South Lawndale Avenue   Lawndale      South
# 32  way/163767789       2520  South Lawndale Avenue   Lawndale      South
# 33  way/163767790       2520   South Millard Avenue    Millard      South
# 34  way/163767803       2521  South Lawndale Avenue   Lawndale      South
# 35  way/163767817       2522  South Lawndale Avenue   Lawndale      South
# 37  way/163767841       2525  South Lawndale Avenue   Lawndale      South
# 39  way/163767871       2528   South Millard Avenue    Millard      South
# ..            ...        ...                    ...        ...        ...
# 63  way/163768469       2638  South Lawndale Avenue   Lawndale      South
# 64  way/163769415       3624       West 26th Street       26th       West
# 65  way/163769418       3644       West 26th Street       26th       West
# 66  way/163769419  3648-3658       West 26th Street       26th       West
# 67  way/163769422  3651-3655       West 25th Street       25th       West
# 68  way/163770241  3651-3655       West 25th Street       25th       West
# 69  way/163770261  3651-3655       West 25th Street       25th       West
# 70  way/163770304  3651-3655       West 25th Street       25th       West
# 71  way/163770452  3651-3655       West 25th Street       25th       West
# 72  way/163770542  3651-3655       West 25th Street       25th       West
# 73  way/163770544  3651-3655       West 25th Street       25th       West
# 74  way/163770569  3651-3655       West 25th Street       25th       West
# 75  way/163770731  3651-3655       West 25th Street       25th       West
# 76  way/163771006  3651-3655       West 25th Street       25th       West
# 77  way/163771118  3651-3655       West 25th Street       25th       West
# 78  way/163771146  3651-3655       West 25th Street       25th       West
# 79  way/163771150  3651-3655       West 25th Street       25th       West
# 80  way/163771164  3651-3655       West 25th Street       25th       West
# 81  way/163771199  3651-3655       West 25th Street       25th       West
# 82  way/163771386  3651-3655       West 25th Street       25th       West
# 83  way/163771436  3651-3655       West 25th Street       25th       West
# 84  way/163771761  3651-3655       West 25th Street       25th       West
# 85  way/163771859  3651-3655       West 25th Street       25th       West
# 86  way/163771890  3651-3655       West 25th Street       25th       West
# 87  way/163771934  3651-3655       West 25th Street       25th       West
# 88  way/163772020  3651-3655       West 25th Street       25th       West
# 89  way/163772071  3651-3655       West 25th Street       25th       West
# 90  way/163772132  3651-3655       West 25th Street       25th       West
# 91  way/163772170  3651-3655       West 25th Street       25th       West
# 92  way/405330603  3651-3655       West 25th Street       25th       West
#
#    building building_l shape_type lat_scoop lon_scoop         lat_center  \
# 0       yes          2    Polygon    41.846   -87.717  41.84650960512757
# 2       yes          3    Polygon    41.846   -87.717  41.84648109184263
# 3       yes          2    Polygon    41.846   -87.716   41.8464311907146
# 4       yes          2    Polygon    41.846   -87.717  41.84642069292985
# 5       yes          2    Polygon    41.846   -87.717  41.84636960337455
# 6       yes          2    Polygon    41.846   -87.717  41.84631333683656
# 7       yes          2    Polygon    41.846   -87.716  41.84632306647141
# 9       yes          2    Polygon    41.846   -87.717   41.8460560082056
# 10      yes          3    Polygon    41.846   -87.716   41.8460737203175
# 12      yes          1    Polygon    41.845   -87.716  41.84598110265578
# 13      yes          1    Polygon    41.845   -87.717  41.84596015538418
# 14      yes          2    Polygon    41.845   -87.717  41.84593256973168
# 15      yes          2    Polygon    41.845   -87.716  41.84592256026706
# 16      yes          1    Polygon    41.845   -87.717    41.845863773618
# 17      yes          2    Polygon    41.845   -87.716   41.8458970234194
# 19      yes          1    Polygon    41.845   -87.717  41.84578853365763
# 20      yes          2    Polygon    41.845   -87.716  41.84580194782377
# 21      yes          2    Polygon    41.845   -87.717  41.84581510329302
# 23      yes          1    Polygon    41.845   -87.717  41.84569650455933
# 24      yes          2    Polygon    41.845   -87.716  41.84569958223857
# 25      yes          2    Polygon    41.845   -87.717  41.84573679865844
# 27      yes          1    Polygon    41.845   -87.716  41.84565552176141
# 29      yes          2    Polygon    41.845   -87.716  41.84561030426056
# 30      yes          1    Polygon    41.845   -87.717   41.8455855577733
# 32      yes          1    Polygon    41.845   -87.717      41.8456078761
# 33      yes          1    Polygon    41.845   -87.716  41.84551917225875
# 34      yes          1    Polygon    41.845   -87.716  41.84551781090772
# 35      yes          1    Polygon    41.845   -87.717  41.84544055405014
# 37      yes          1    Polygon    41.845   -87.716  41.84544919113429
# 39      yes          2    Polygon    41.845   -87.716  41.84536979054833
# ..      ...        ...        ...       ...       ...                ...
# 63      yes          2    Polygon    41.845   -87.717   41.8450429247331
# 64      yes          2    Polygon    41.845   -87.716  41.84511095333855
# 65      yes          2    Polygon    41.844   -87.716  41.84458643622082
# 66      yes          1    Polygon    41.844   -87.716  41.84455846001572
# 67      yes          3    Polygon    41.846   -87.716  41.84606098862837
# 68      yes          3    Polygon    41.846   -87.716  41.84632910896719
# 69      yes          3    Polygon    41.845   -87.716  41.84570352023145
# 70      yes          3    Polygon    41.845   -87.716  41.84566145667257
# 71      yes          3    Polygon    41.845   -87.716  41.84581763133807
# 72      yes          3    Polygon    41.845   -87.716  41.84552627569926
# 73      yes          3    Polygon    41.845   -87.716  41.84562606772255
# 74      yes          3    Polygon    41.845   -87.716        41.84523045
# 75      yes          3    Polygon    41.844   -87.716  41.84497130847836
# 76      yes          3    Polygon    41.845   -87.716  41.84545421887947
# 77      yes          3    Polygon    41.845   -87.716  41.84553336232307
# 78      yes          3    Polygon    41.845   -87.716  41.84521476665608
# 79      yes          3    Polygon    41.846   -87.716  41.84643145315182
# 80      yes          3    Polygon    41.845   -87.716  41.84504427855078
# 81      yes          3    Polygon    41.845   -87.716  41.84598205046367
# 82      yes          3    Polygon    41.844   -87.716         41.8448334
# 83      yes          3    Polygon    41.845   -87.716  41.84511115662571
# 84      yes          3    Polygon    41.845   -87.716  41.84538299066892
# 85      yes          3    Polygon    41.844   -87.716  41.84476458211859
# 86      yes          3    Polygon    41.845   -87.716  41.84533989912025
# 87      yes          3    Polygon    41.845   -87.716  41.84580371636711
# 88      yes          3    Polygon    41.845   -87.716  41.84587703675367
# 89      yes          3    Polygon    41.845   -87.716  41.84544864999999
# 90      yes          3    Polygon    41.844   -87.716  41.84490021519576
# 91      yes          3    Polygon    41.845   -87.716  41.84573769474812
# 92      yes          3    Polygon    41.846   -87.716  41.84633571792221
#
#             lon_center                                           geometry
# 0   -87.71703814927186  POLYGON ((-87.7171232 41.8464752, -87.71712309...
# 2   -87.71759474590094  POLYGON ((-87.7175713 41.8464392, -87.7175877 ...
# 3   -87.71636055067256  POLYGON ((-87.71636599999999 41.846397, -87.71...
# 4   -87.71702471950471  POLYGON ((-87.71712220000001 41.8463833, -87.7...
# 5   -87.71757841554287  POLYGON ((-87.7174859 41.846344, -87.7176695 4...
# 6   -87.71757668909439  POLYGON ((-87.7174859 41.846344, -87.7174828 4...
# 7   -87.71699989606041  POLYGON ((-87.7171195 41.8462831, -87.7171304 ...
# 9   -87.71756770040085  POLYGON ((-87.71754610000001 41.8459958, -87.7...
# 10  -87.71641003797632  POLYGON ((-87.7166117 41.8460361, -87.7166129 ...
# 12  -87.71634480887434  POLYGON ((-87.7164217 41.8459445, -87.7164216 ...
# 13  -87.71702204325908  POLYGON ((-87.71710090000001 41.8459235, -87.7...
# 14  -87.71756505789992  POLYGON ((-87.71766820000001 41.8459018, -87.7...
# 15  -87.71678300651092  POLYGON ((-87.7168685 41.8458564, -87.7168728 ...
# 16  -87.71754821084377  POLYGON ((-87.7176102 41.845826, -87.7176303 4...
# 17  -87.71631876729404  POLYGON ((-87.7163896 41.8458565, -87.71641889...
# 19  -87.71755616812749  POLYGON ((-87.71752840000001 41.8457433, -87.7...
# 20  -87.71634046171401  POLYGON ((-87.7164271 41.8457662, -87.7164283 ...
# 21  -87.71701380957526  POLYGON ((-87.7170986 41.8457835, -87.71709850...
# 23  -87.71755408668101  POLYGON ((-87.71764109999999 41.8456629, -87.7...
# 24  -87.71631877064415  POLYGON ((-87.71629419999999 41.8456584, -87.7...
# 25  -87.71701193155326  POLYGON ((-87.7169452 41.8457058, -87.7169452 ...
# 27  -87.71698553003193  POLYGON ((-87.717091 41.8456215, -87.7170922 4...
# 29  -87.71631684433572  POLYGON ((-87.71627119999999 41.8455664, -87.7...
# 30  -87.71700857438934  POLYGON ((-87.7170622 41.8455555, -87.7170842 ...
# 32  -87.71755762453604  POLYGON ((-87.71766580000001 41.8455739, -87.7...
# 33  -87.71632045479923  POLYGON ((-87.71630879999999 41.8454733, -87.7...
# 34  -87.71699589568966  POLYGON ((-87.7171125 41.8454845, -87.71711190...
# 35  -87.71764515135615  POLYGON ((-87.71743840000001 41.8453709, -87.7...
# 37  -87.71699601452605  POLYGON ((-87.7170838 41.8454157, -87.7170837 ...
# 39  -87.71629601956801  POLYGON ((-87.716347 41.8453239, -87.716398299...
# ..                 ...                                                ...
# 63  -87.71752735361547  POLYGON ((-87.7175666 41.8450121, -87.7175683 ...
# 64  -87.71628077583702  POLYGON ((-87.7163561 41.8450798, -87.7163556 ...
# 65  -87.71636526894545  POLYGON ((-87.7165957 41.8444512, -87.71660060...
# 66  -87.71688647557201  POLYGON ((-87.7170931 41.8444443, -87.71711500...
# 67  -87.71692200184826  POLYGON ((-87.7171037 41.8460168, -87.71710659...
# 68  -87.71674652521912  POLYGON ((-87.7167836 41.8462881, -87.71678470...
# 69  -87.71657836405561  POLYGON ((-87.71662070000001 41.8456739, -87.7...
# 70  -87.71673092488648  POLYGON ((-87.7166927 41.8456304, -87.7167697 ...
# 71  -87.71674120678969  POLYGON ((-87.71678300000001 41.8457846, -87.7...
# 72  -87.71672023968779  POLYGON ((-87.71675449999999 41.8454963, -87.7...
# 73  -87.71657413122153  POLYGON ((-87.71661949999999 41.8456026, -87.7...
# 74         -87.7165708  POLYGON ((-87.71660869999999 41.8452018, -87.7...
# 75   -87.7167114088807  POLYGON ((-87.7167544 41.8449378, -87.71675740...
# 76  -87.71672371386012  POLYGON ((-87.7167644 41.8454222, -87.7167656 ...
# 77  -87.71659013129627  POLYGON ((-87.7166076 41.8455119, -87.7166091 ...
# 78   -87.7167196166756  POLYGON ((-87.7167577 41.8451697, -87.7167623 ...
# 79  -87.71675425348378  POLYGON ((-87.71679349999999 41.8464034, -87.7...
# 80  -87.71671774809806  POLYGON ((-87.7167573 41.8450146, -87.71675860...
# 81   -87.7165756543321  POLYGON ((-87.716618 41.8459497, -87.7166174 4...
# 82  -87.71673059999999  POLYGON ((-87.7167905 41.8448049, -87.7167918 ...
# 83   -87.7167196752204  POLYGON ((-87.71676220000001 41.8450764, -87.7...
# 84   -87.7165530125131  POLYGON ((-87.7166036 41.84535, -87.7166048 41...
# 85  -87.71673493407533  POLYGON ((-87.7168041 41.8447295, -87.7168034 ...
# 86  -87.71674377431549  POLYGON ((-87.71669420000001 41.8452857, -87.7...
# 87  -87.71658561801006  POLYGON ((-87.7166216 41.8457755, -87.7166228 ...
# 88  -87.71658267025472  POLYGON ((-87.71662449999999 41.8458537, -87.7...
# 89         -87.7165779  POLYGON ((-87.7166158 41.8454159, -87.7166189 ...
# 90  -87.71672188758045  POLYGON ((-87.71676600000001 41.844872, -87.71...
# 91  -87.71675312468233  POLYGON ((-87.7168113 41.8456996, -87.71681239...
# 92  -87.71640598445104  POLYGON ((-87.716632 41.8463713, -87.716185999...
#
# [78 rows x 13 columns]

# %%
property_parcel = gpd.read_file(property_parcel_shape_file_path)
print (property_parcel.shape)
property_parcel.head()
# Out:
# (93, 13)
#        parcel_id house_numb             street_add street_nam street_pre  \
# 0  way/163767492       2451  South Lawndale Avenue   Lawndale      South
# 1  way/163767493       2451   South Millard Avenue    Millard      South
# 2  way/163767501       2452  South Lawndale Avenue   Lawndale      South
# 3  way/163767522       2454   South Millard Avenue    Millard      South
# 4  way/163767530       2455  South Lawndale Avenue   Lawndale      South
#
#   building building_l shape_type lat_scoop lon_scoop         lat_center  \
# 0      yes          2    Polygon    41.846   -87.717  41.84650960512757
# 1      yes          2    Polygon    41.846   -87.715  41.84652377513783
# 2      yes          3    Polygon    41.846   -87.717  41.84648109184263
# 3      yes          2    Polygon    41.846   -87.716   41.8464311907146
# 4      yes          2    Polygon    41.846   -87.717  41.84642069292985
#
#            lon_center                                           geometry
# 0  -87.71703814927186  POLYGON ((-87.7171232 41.8464752, -87.71712309...
# 1  -87.71582629867582  POLYGON ((-87.7159137 41.8464865, -87.71591549...
# 2  -87.71759474590094  POLYGON ((-87.7175713 41.8464392, -87.7175877 ...
# 3  -87.71636055067256  POLYGON ((-87.71636599999999 41.846397, -87.71...
# 4  -87.71702471950471  POLYGON ((-87.71712220000001 41.8463833, -87.7...

# %%
csvData.loc[0,'geometry'].area
# Out:
# 1.2003820000129982e-08

# %%
county_data = gpd.read_file(county_data_path)
print (county_data.shape)
county_data.head()
# Out:
# (3233, 10)
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME LSAD  \
# 0      19      107  00465242  0500000US19107  19107     Keokuk   06
# 1      19      189  00465283  0500000US19189  19189  Winnebago   06
# 2      20      093  00485011  0500000US20093  20093     Kearny   06
# 3      20      123  00485026  0500000US20123  20123   Mitchell   06
# 4      20      187  00485055  0500000US20187  20187    Stanton   06
#
#         ALAND    AWATER                                           geometry
# 0  1500067253   1929323  POLYGON ((-92.41199499999999 41.509548, -92.35...
# 1  1037261946   3182052  POLYGON ((-93.97076 43.499605, -93.88843009910...
# 2  2254696689   1133601  POLYGON ((-101.54192 37.914575, -101.541863 37...
# 3  1817632928  44979981  POLYGON ((-98.49006799999999 39.241666, -98.49...
# 4  1762104518    178555  POLYGON ((-102.041899 37.541186, -102.041894 3...

# %%
county_data['NAME'] = county_data['NAME'].str.lower()
cook_county = county_data[(county_data['NAME'] == 'cook') & (county_data['GEOID'] == '17031')]

# %%
from plot import GeoPlot
# 'Circle', 'Large', 'Medium
obj_GP = GeoPlot()
obj_GP.set_figure(lenXaxis=30, lenYaxis=15)
obj_GP.base_plot(color='white', dataIN=cook_county)
obj_GP.add_plot(csvData, shapePlot=True)
obj_GP.show()

# %%
# Out:
#     STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID  NAME LSAD       ALAND  \
# 366      17      031  01784766  0500000US17031  17031  cook   06  2447516257
#
#          AWATER                                           geometry
# 366  1786450196  POLYGON ((-88.263289 42.023056, -88.2632759999...

# %%
np.unique(csvData['type'])
# Out:
# array(['', 'Circle', 'Large', 'Medium'], dtype=object)

# %%
https://dev.virtualearth.net/REST/v1/Imagery/Metadata/Aerial/42.22353,-87.98569/19?mapSize=256,256&o=json&key=As1SMhbktDgHnBoak6XDezSKFHbgjCqLW4CAVx2s2601KLW_y6cM6vk5qb2C-wFA

# %%
https://dev.virtualearth.net/REST/v1/Imagery/Metadata/Aerial/42.22353,-87.98569/19?mapSize=256,256&o=json&he=1&key=As1SMhbktDgHnBoak6XDezSKFHbgjCqLW4CAVx2s2601KLW_y6cM6vk5qb2C-wFA
# Out:
#   File "<ipython-input-7-45ddccc1457e>", line 1
#     https://dev.virtualearth.net/REST/v1/Imagery/Metadata/Aerial/42.25162,-88.19634/19?mapSize=256,256&he=1&o=json&key=As1SMhbktDgHnBoak6XDezSKFHbgjCqLW4CAVx2s2601KLW_y6cM6vk5qb2C-wFA
#          ^
# SyntaxError: invalid syntax

# %%
{"authenticationResultCode":"ValidCredentials","brandLogoUri":"http:\/\/dev.virtualearth.net\/Branding\/logo_powered_by.png","copyright":"Copyright © 2018 Microsoft and its suppliers. All rights reserved. This API cannot be accessed and the content and any results may not be used, reproduced or transmitted in any manner without express written permission from Microsoft Corporation.","resourceSets":[{"estimatedTotal":1,"resources":[{"__type":"Location:http:\/\/schemas.microsoft.com\/search\/local\/ws\/rest\/v1","bbox":[42.2196672824293,-87.9926444572881,42.2273927175707,-87.9787355427119],"name":"920 N Lakeside Dr, Vernon Hills, IL 60061","point":{"type":"Point","coordinates":[42.22353,-87.98569]},"address":{"addressLine":"920 N Lakeside Dr","adminDistrict":"IL","adminDistrict2":"Lake County","countryRegion":"United States","formattedAddress":"920 N Lakeside Dr, Vernon Hills, IL 60061","locality":"Vernon Hills","postalCode":"60061"},"confidence":"High","entityType":"Address","geocodePoints":[{"type":"Point","coordinates":[42.22353,-87.98569],"calculationMethod":"Rooftop","usageTypes":["Display"]},{"type":"Point","coordinates":[42.2232396395457,-87.9847702060638],"calculationMethod":"Rooftop","usageTypes":["Route"]}],"matchCodes":["Good"]}]}],"statusCode":200,"statusDescription":"OK","traceId":"81a80798cbf14182ab9712c4f5f3cd50|CH1AECCD03|7.7.0.0|Ref A: 8651E50FCEBA4ACDA46F9DB0BBDBD207 Ref B: CH1EDGE1121 Ref C: 2018-02-23T02:54:46Z"}

# %%
http://ecn.t3.tiles.virtualearth.net/tiles/a0302222123121112103.jpeg?g=6301

# %%
http://ecn.t0.tiles.virtualearth.net/tiles/a0302222123003020030.jpeg?g=6301

# %%
https://dev.virtualearth.net/REST/v1/Imagery/Metadata/Aerial/42.22353,-87.98569?mapSize=256,256&o=json&key=As1SMhbktDgHnBoak6XDezSKFHbgjCqLW4CAVx2s2601KLW_y6cM6vk5qb2C-wFA

# %%
https://dev.virtualearth.net/REST/v1/Imagery/Metadata/CanvasDark/42.22353,-87.98569/16?mapSize=256,256&o=json&he=1&key=As1SMhbktDgHnBoak6XDezSKFHbgjCqLW4CAVx2s2601KLW_y6cM6vk5qb2C-wFA

# %%
http://ak.dynamic.t3.tiles.virtualearth.net/comp/ch/0302222123121112?mkt=en-US&it=G,L&cstl=WD&og=238&n=z
