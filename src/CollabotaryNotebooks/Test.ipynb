# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7b297b7-0527-453f-a57c-9ec5d71c1e52" name="files[]" multiple disabled />
#      <output id="result-f7b297b7-0527-453f-a57c-9ec5d71c1e52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"</script>
# MessageErrorTraceback (most recent call last)
# <ipython-input-3-21dc3c638f66> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python2.7/dist-packages/google/colab/files.pyc in upload()
#      59   result = output.eval_js(
#      60       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 61           input_id=input_id, output_id=output_id))
#      62   files = collections.defaultdict(six.binary_type)
#      63
#
# ...

# %%
from conv_net import run
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-4-34be046e904c> in <module>()
# ----> 1 from conv_net import run
#
# ImportError: No module named conv_net
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
