# %% [markdown]
# ## Notes:
# ----------
#
# Theory:
# We have see a lot of discreapancy with the images, hence for testing puspose we only select images that were last_reviewed after September 2017. We believe that the data atleast reviewed after september should be correct.
#
# 1. The accessor photo column had some "nan" values, these were removed.
# 2.
#
#
#
#
# ## WHAT THE BELOW CELLS DO:
#
# 1. We load the metadata file that contains the property metadata for appx 250000 properties including the assessor image.
# 3. We dont want to experiment on all the images, so we select the ones that were last_reviewed after April 2017. We further filter the images. For land the images that have a improvement level as land are only selected. For House, images with improvement level of anything other than land is taken.
# 4. We then collect all the assessor images from the links provided in the metadata table. Somtimes the images are not rendered properly, so we filter such images
# 5. Similarly we gather all the Aerial images using Bing map API call
# 6. Lastely we acquire all streeside images from Google.
# 7. We can even gather all the Aerial images using Google map API call

# %%
import os
import random
import pandas as pd
import numpy as np
import logging

logging.basicConfig(level=logging.DEBUG, filename="logfile.log", filemode="w", 
                    format="%(asctime)-15s %(levelname)-8s %(message)s")

from external_data import bing_aerial, google_streetside, google_aerial
from config import pathDict

parent_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/'
meta_data_path = os.path.join(parent_path, "house_metadata_nw.csv")
assessor_image_path = os.path.join(parent_path, "input_images", "assessor_images")
bing_aerial_image_path = os.path.join(parent_path, 'input_images','bing','aerial_images')
google_aerial_image_path = os.path.join(parent_path, 'input_images','google','aerial_images')
streetside_image_path = os.path.join(parent_path, 'input_images','streetside_images')

print('Metadata path: ', meta_data_path)
print('Assessor image path: ', assessor_image_path)
print('Aerial image path (Bing): ', bing_aerial_image_path)
print('Streetside image path: ', streetside_image_path)
print('Aerial image path (Google): ', google_aerial_image_path)

dump_assesor_images = False
rmv_bad_assessor_images = False
dump_aerial_images  = False
rmv_bad_aerial_images = False
dump_streetside_images  = False
rmv_bad_streetside_images = False
dump_aerial_google_images  = True
# Out:
# Metadata path:  /Users/sam/All-Program/App-DataSet/HouseClassification/house_metadata_nw.csv
# Assessor image path:  /Users/sam/All-Program/App-DataSet/HouseClassification/input_images/assessor_images
# Aerial image path (Bing):  /Users/sam/All-Program/App-DataSet/HouseClassification/input_images/bing/aerial_images
# Streetside image path:  /Users/sam/All-Program/App-DataSet/HouseClassification/input_images/streetside_images
# Aerial image path (Google):  /Users/sam/All-Program/App-DataSet/HouseClassification/input_images/google/aerial_images

# %%
def collateData(filesPath, fileType="csv"):
    fileDirList = [os.path.join(filesPath, files) for files in
                   os.listdir(filesPath) if files.endswith('.%s' % fileType)]
    if fileType == "csv":
        rowList = []
        # fileDirList = [files for files in listdir if files.endswith('.csv')]
        for files in fileDirList:
            df = pd.read_csv(files, header=0)
            rowList.append(df)
        return pd.concat(rowList)
    elif fileType == "json":
        dataOUT = {}
        for files in fileDirList:
            jsonFilepath = os.path.join(filesPath, files)
            with open(jsonFilepath, 'r') as fileIN:
                dataOUT = merge(dataOUT, json.load(fileIN))
        return dataOUT

# %% [markdown]
# # STEP 1: Load Metadata file
# ------------

# %%
metadata = pd.read_csv(meta_data_path)
metadata.columns = ['row_id', 'removed', 'property_id', 'state', 'county_name', 'pin',
       'address_line1', 'address_line2', 'address_city', 'address_zip',
       'zoning', 'improvement_level', 'type', 'exterior',
       'last_reviewed_timestamp', 'gone_timestamp', 'indicator',
       'assessor_photo']
metadata['state'] = metadata['state'].astype('str')
metadata['county_name'] = metadata['county_name'].astype('str')
metadata['pin'] = metadata['pin'].astype('str')
metadata['address_line1'] = metadata['address_line1'].astype('str')
metadata['address_line2'] = metadata['address_line2'].astype('str')
metadata['address_city'] = metadata['address_city'].astype('str')
metadata['address_zip'] = metadata['address_zip'].astype('str')
metadata['zoning'] = metadata['zoning'].astype('str')
metadata['improvement_level'] = metadata['improvement_level'].astype('str')
metadata['type'] = metadata['type'].astype('str')
metadata['exterior'] = metadata['exterior'].astype('str')
metadata['last_reviewed_timestamp'] = pd.to_datetime(metadata['last_reviewed_timestamp'])#.astype('str')
metadata['gone_timestamp'] = pd.to_datetime(metadata['gone_timestamp'])#.astype('str')
metadata['indicator'] = metadata['indicator'].astype('str')
metadata['assessor_photo'] = metadata['assessor_photo'].astype('str')

# Remove the Test Dat from Metadata
metadata = metadata[metadata['removed'] == 0]
print(metadata.shape)
metadata.head(3)
# Out:
# /Users/sam/App-Setup/anaconda/envs/anaconda35/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (220364, 18)
#    row_id  removed  property_id state county_name                 pin  \
# 1       1        0       499849    IL        Cook  01-01-100-109-0000
# 2       2        0       499852    IL        Cook  01-01-101-029-0000
# 3       3        0       499854    IL        Cook  01-01-109-001-0000
#
#    address_line1 address_line2 address_city  address_zip       zoning  \
# 1  200S HOUGH ST           nan   BARRINGTON          nan       Vacant
# 2      201 First    22 # Floor   BARRINGTON          nan       Vacant
# 3    323 MAIN ST           nan   BARRINGTON  600104305.0  Residential
#
#   improvement_level             type exterior last_reviewed_timestamp  \
# 1              Land              nan      nan                     NaT
# 2              Land  4 Unit Apt Bldg    Frame                     NaT
# 3          Improved           2 Flat    Frame 2017-05-25 04:42:26.850
#
#   gone_timestamp     indicator  \
# 1            NaT   Likely Land
# 2            NaT   Likely Land
# 3            NaT  Likely House
#
#                                       assessor_photo
# 1  http://www.cookcountyassessor.com/PropertyImag...
# 2  http://www.cookcountyassessor.com/PropertyImag...
# 3  http://www.cookcountyassessor.com/PropertyImag...

# %% [markdown]
# # STEP 2: Create a new Subset
# --------------

# %%
metadata_lst_rvd_valid = metadata[metadata['last_reviewed_timestamp'] != '']
metadata_lst_rvd_valid['last_reviewed_timestamp'] = pd.to_datetime(metadata_lst_rvd_valid['last_reviewed_timestamp'])
metadata_lst_rvd_valid_2017 = metadata_lst_rvd_valid[((metadata_lst_rvd_valid['last_reviewed_timestamp'].dt.year == 2017) & 
                                                     (metadata_lst_rvd_valid['last_reviewed_timestamp'].dt.month >=1 ) &
#                                                       (metadata_lst_rvd_valid['last_reviewed_timestamp'].dt.month <7) &
                                                      (metadata_lst_rvd_valid['address_city'].str.lower().str.strip().str.match('chicago')) &
                                                      (metadata_lst_rvd_valid['address_line1'] != 'nan') &
                                                      (metadata_lst_rvd_valid['assessor_photo'] != 'nan') &
                                                     (metadata_lst_rvd_valid['indicator'].isin(["Likely House", "Likely Land"]) ))]
image_data = metadata_lst_rvd_valid_2017
print (metadata_lst_rvd_valid_2017.shape)
metadata_lst_rvd_valid_2017.head(2)
# Out:
# (28527, 18)
#       row_id  removed  property_id state county_name                 pin  \
# 6111    6111        0       506508    IL        Cook  09-25-417-038-0000
# 8746    8746        0       509513    IL        Cook  10-25-300-045-0000
#
#             address_line1 address_line2 address_city  address_zip  \
# 6111  7334 N OLEANDER AVE           nan      CHICAGO  606314308.0
# 8746    3125 W HOWARD ST            nan     CHICAGO   606451139.0
#
#            zoning improvement_level type exterior last_reviewed_timestamp  \
# 6111  Residential          Improved  nan      nan 2017-02-15 21:27:08.760
# 8746       Vacant              Land  nan      nan 2017-06-09 22:51:31.103
#
#      gone_timestamp     indicator  \
# 6111            NaT  Likely House
# 8746            NaT   Likely Land
#
#                                          assessor_photo
# 6111  http://www.cookcountyassessor.com/PropertyImag...
# 8746  http://www.cookcountyassessor.com/PropertyImag...

# %% [markdown]
# ### LAND DATA
# ----------------

# %%
land_data = image_data[(image_data['indicator'] == 'Likely Land') & (image_data['improvement_level'] == 'Land')]
print (np.unique(np.array(land_data['improvement_level'])))
print (land_data.shape)
land_data.head(3)
# Out:
# ['Land']
# (9873, 18)
#       row_id  removed  property_id state county_name                 pin  \
# 8746    8746        0       509513    IL        Cook  10-25-300-045-0000
# 9339    9339        0       510240    IL        Cook  10-31-417-045-0000
# 9366    9366        0       510267    IL        Cook  10-32-126-007-0000
#
#           address_line1 address_line2 address_city  address_zip  zoning  \
# 8746  3125 W HOWARD ST            nan     CHICAGO   606451139.0  Vacant
# 9339  6546 W DEVON AVE            nan     CHICAGO   606312038.0  Vacant
# 9366  7046N MCALPIN AVE           nan      CHICAGO      60646.0  Vacant
#
#      improvement_level type exterior last_reviewed_timestamp gone_timestamp  \
# 8746              Land  nan      nan 2017-06-09 22:51:31.103            NaT
# 9339              Land  nan      nan 2017-06-22 18:07:04.937            NaT
# 9366              Land  nan      nan 2017-06-09 22:51:31.103            NaT
#
#         indicator                                     assessor_photo
# 8746  Likely Land  http://www.cookcountyassessor.com/PropertyImag...
# 9339  Likely Land  http://www.cookcountyassessor.com/PropertyImag...
# 9366  Likely Land  http://www.cookcountyassessor.com/PropertyImag...

# %% [markdown]
# ### HOUSE DATA
# --------------

# %%
house_data = image_data[(image_data['indicator'] == 'Likely House') & (image_data['improvement_level'] != 'Land')]
print (np.unique(np.array(house_data['improvement_level'])))
print (house_data.shape)
house_data.head(3)
# Out:
# ['Condominium' 'Improved' 'Minor Improvement' 'Mixed Use']
# (18392, 18)
#       row_id  removed  property_id state county_name                 pin  \
# 6111    6111        0       506508    IL        Cook  09-25-417-038-0000
# 8761    8761        0       509531    IL        Cook  10-25-308-043-0000
# 8769    8769        0       509539    IL        Cook  10-25-314-003-0000
#
#             address_line1 address_line2 address_city  address_zip  \
# 6111  7334 N OLEANDER AVE           nan      CHICAGO  606314308.0
# 8761      3146W FARGO AVE           nan      CHICAGO      60645.0
# 8769      2949W FARGO AVE           nan      CHICAGO      60645.0
#
#            zoning improvement_level type exterior last_reviewed_timestamp  \
# 6111  Residential          Improved  nan      nan 2017-02-15 21:27:08.760
# 8761  Residential          Improved  nan      nan 2017-02-10 21:21:30.520
# 8769  Residential          Improved  nan      nan 2017-02-23 16:25:51.033
#
#      gone_timestamp     indicator  \
# 6111            NaT  Likely House
# 8761            NaT  Likely House
# 8769            NaT  Likely House
#
#                                          assessor_photo
# 6111  http://www.cookcountyassessor.com/PropertyImag...
# 8761  http://www.cookcountyassessor.com/PropertyImag...
# 8769  http://www.cookcountyassessor.com/PropertyImag...

# %% [markdown]
# ### UNKNOWN DATA
# -------------

# %%
unknown_data = image_data[image_data['indicator'] == 'Unknown']
print (unknown_data.shape)
unknown_data.head(3)
# Out:
# (0, 18)
# Empty DataFrame
# Columns: [row_id, removed, property_id, state, county_name, pin, address_line1, address_line2, address_city, address_zip, zoning, improvement_level, type, exterior, last_reviewed_timestamp, gone_timestamp, indicator, assessor_photo]
# Index: []

# %% [markdown]
# # Step 3: Load Assessor Images
# ------------

# %%
import urllib.request
import requests
import os


def upload_assessor_data(dataIN, dump_path, how_many_images): 
    if how_many_images:
        if how_many_images > len(dataIN):
            raise ValueError ('The random sample cannot exceed the dataIN length')
        random.seed(8792)
        random_indices = random.sample(range(1, len(dataIN)+1), how_many_images)
        random_indices = np.sort(np.array(random_indices, dtype='int32'))    
        dataIN.loc[:,'row_num'] = np.arange(1, len(dataIN)+1)
        dataIN = dataIN[dataIN['row_num'].isin(random_indices)]
    print ('Total images to be loaded is:', dataIN.shape)
    i = 0
    j = 0
    for  row_id, pin, pic_url in np.array(dataIN[['row_id', 'pin', 'assessor_photo']]):
#         print (pic_url)
        response = requests.get(pic_url)
        if response.status_code == 200:
            imagepath = os.path.join(dump_path, '%s.jpg'%(str(pin)))
            with open(imagepath, 'wb') as f:
                f.write(response.content)
            i+=1
        else:
            j += 1
        
        b = "TOTAL IMAGES PARSED ======== %s"
        print (b%(i), end="\r")
    print ('')
    print ("TOTAL FAULTY IMAGES ==== ", j)

# %% [markdown]
# #### LOAD LAND IMAGES

# %%
if dump_assesor_images:
    assessor_land_dump_path = os.path.join(assessor_image_path, 'land')
    upload_assessor_data(dataIN=land_data, dump_path=assessor_land_dump_path, how_many_images=None) # 5000
# Out:
# Total images to be loaded is: (14413, 18)
# TOTAL IMAGES PARSED ======== 14413
# TOTAL FAULTY IMAGES ====  0

# %% [markdown]
# #### LOAD HOUSE IMAGES

# %%
if dump_assesor_images:
    assessor_house_dump_path = os.path.join(assessor_image_path, 'house')
    upload_assessor_data(dataIN=house_data, dump_path=assessor_house_dump_path, how_many_images=None) #
# Out:
# Total images to be loaded is: (6441, 18)
# TOTAL IMAGES PARSED ======== 6441
# TOTAL FAULTY IMAGES ====  0

# %% [markdown]
# ### REMOVE NOT-AVAILABLE IMAGES
# ------------------

# %%
from scipy import misc
def remove_not_available_data(image_path):
    image_path = [os.path.join(image_path, img) for img in os.listdir(image_path) if img != ".DS_Store"]
    not_available_image_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/input_images/assessor_image_na.jpg'
    bad_data = misc.imread(not_available_image_path)
    bad_data = misc.imresize(bad_data, [160,160])
    faulty_img = 0
    for path in image_path:
        data = misc.imread(path)
        data = misc.imresize(data, [160,160])
        if (bad_data == data).all():
            faulty_img += 1
            os.remove(path)
    print ('Total Faulty images: ', faulty_img)

# %%
if rmv_bad_assessor_images:
    assessor_land_dump_path = os.path.join(assessor_image_path, 'land')
    assessor_house_dump_path = os.path.join(assessor_image_path, 'house')
    remove_not_available_data(image_path=assessor_land_dump_path)
    remove_not_available_data(image_path=assessor_house_dump_path)

# %% [markdown]
# # Step 4: Load Aerial Images:
# ------------

# %% [markdown]
# ### Aerial Land and House DUMP

# %%
land_house_data = pd.concat([land_data, house_data])
print (land_house_data.shape)
pd.concat([land_house_data.head(2), land_house_data.tail(2)])
# Out:
# (20854, 18)
#         row_id  removed  property_id state county_name                 pin  \
# 34          34        0       499887    IL        Cook  01-01-406-017-0000
# 35          35        0       499888    IL        Cook  01-01-407-008-0000
# 223392  223392        0      1426092    IL        Cook  17-30-105-004-0000
# 223393  223393        0      1426093    IL        Cook  17-30-112-038-0000
#
#            address_line1 address_line2 address_city address_zip       zoning  \
# 34      901 PRAIRIE AVE            nan   BARRINGTON         nan       Vacant
# 35       920 PRAIRIE AVE           nan   BARRINGTON         nan       Vacant
# 223392     2051 W CERMAK           nan      CHICAGO       60608  Residential
# 223393       2337 W 23RD           nan      CHICAGO       60608  Residential
#
#        improvement_level type exterior last_reviewed_timestamp gone_timestamp  \
# 34                  Land  nan      nan 2017-06-09 22:51:31.103            NaT
# 35                  Land  nan      nan 2017-06-09 22:51:31.103            NaT
# 223392         Mixed Use  nan      nan 2017-06-23 15:07:43.277            NaT
# 223393          Improved  nan      nan 2017-06-23 15:07:43.277            NaT
#
#            indicator                                     assessor_photo
# 34       Likely Land  http://www.cookcountyassessor.com/PropertyImag...
# 35       Likely Land  http://www.cookcountyassessor.com/PropertyImag...
# 223392  Likely House  http://www.cookcountyassessor.com/PropertyImag...
# 223393  Likely House  http://www.cookcountyassessor.com/PropertyImag...

# %%
if dump_aerial_images:
    bing_search.get_image_address(land_house_data, batch_size=500, get_stats=True)
# Out:
# [['01-01-406-017-0000' '901 PRAIRIE AVE ' 'BARRINGTON' 'nan' 'Likely Land']
#  ['01-01-407-008-0000' '920 PRAIRIE AVE' 'BARRINGTON' 'nan' 'Likely Land']
#  ['01-12-103-004-0000' '0 GROVE AVE ' 'BARRINGTON' 'nan' 'Likely Land']
#  ['01-28-101-002-0000' '161 LINDEN AVE' 'DUNDEE' '60010.0' 'Likely Land']
#  ['02-09-108-005-0000' '1223 W DUNDEE RD ' 'PALATINE' '600749212.0'
#   'Likely Land']]
# TOTAL RECORDS PARSED: IMAGES DONE ======== 20853

# %% [markdown]
# #### Load all the Aerial statistics data and check if the url is Nan

# %%
bing_aerial_stats_data = collateData(filesPath=pathDict['bing_aerial_stats_path'], fileType="csv")
bing_aerial_stats_data['img_url'] = bing_aerial_stats_data['img_url'].astype('str')
nan_data = bing_aerial_stats_data[bing_aerial_stats_data['img_url'] == 'nan']
nan_data.head()
#### There are only two images, but this were never stores into the image file, because of the exception handled.
# Out:
# /Users/sam/All-Program/App-DataSet/HouseClassification/statistics/aerial_images/data_loader
#                     pin        city  zip                address  lat  lon  \
# 226  08-30-201-007-0000  SCHAUMBURG  NaN     0 RTE #1-BOX 313A   NaN  NaN
# 51   32-14-200-016-0000    LANSING   NaN  0 ROUTE 394 & JOE RD   NaN  NaN
#
#      zoom_lvl image_fetch    indicator img_url
# 226       NaN         NaN  Likely Land     nan
# 51        NaN         NaN  Likely Land     nan

# %% [markdown]
# # Step 5: Load Streetside Images:
# ------------

# %%
land_house_data = pd.concat([land_data, house_data])
print (land_house_data.shape)
pd.concat([land_house_data.head(2), land_house_data.tail(2)])
# Out:
# (26851, 18)
#         row_id  removed  property_id state county_name                 pin  \
# 34          34        0       499887    IL        Cook  01-01-406-017-0000
# 35          35        0       499888    IL        Cook  01-01-407-008-0000
# 259193  259193        0      1480786    IL        Lake       17-31-102-026
# 259194  259194        0      1480787    IL        Lake       17-31-302-063
#
#                 address_line1 address_line2   address_city address_zip  \
# 34           901 PRAIRIE AVE            nan     BARRINGTON         nan
# 35            920 PRAIRIE AVE           nan     BARRINGTON         nan
# 259193  434 LAKESIDE MANOR RD           nan  HIGHLAND PARK       60035
# 259194        315 SHERIDAN RD           nan  HIGHLAND PARK       60035
#
#              zoning improvement_level type exterior last_reviewed_timestamp  \
# 34           Vacant              Land  nan      nan 2017-06-09 22:51:31.103
# 35           Vacant              Land  nan      nan 2017-06-09 22:51:31.103
# 259193  Residential          Improved  nan      nan 2017-11-01 15:10:56.890
# 259194  Residential          Improved  nan      nan 2017-11-01 15:10:56.890
#
#        gone_timestamp     indicator  \
# 34                NaT   Likely Land
# 35                NaT   Likely Land
# 259193            NaT  Likely House
# 259194            NaT  Likely House
#
#                                            assessor_photo
# 34      http://www.cookcountyassessor.com/PropertyImag...
# 35      http://www.cookcountyassessor.com/PropertyImag...
# 259193  http://apps01.lakecountyil.gov/assessor/images...
# 259194  http://apps01.lakecountyil.gov/assessor/images...

# %%
streetside_land_dump_path = os.path.join(streetside_image_path, 'land')
streetside_house_dump_path = os.path.join(streetside_image_path, 'house')

print (streetside_land_dump_path)
print (streetside_house_dump_path)
# Out:
# /Users/sam/All-Program/App-DataSet/HouseClassification/input_images/streetside_images/land
# /Users/sam/All-Program/App-DataSet/HouseClassification/input_images/streetside_images/house

# %%
if dump_streetside_images:
     google_street_map.get_image_address(land_house_data, batch_size=500, get_stats=True)
# Out:
# TOTAL RECORDS PARSED: IMAGES DONE ======== 26850

# %% [markdown]
# ### Remove the not-available images

# %%
from scipy import misc
def remove_not_available_data(image_path):
    image_path = [os.path.join(image_path, img) for img in os.listdir(image_path) if img != ".DS_Store"]
    not_available_image_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/input_images/streetside_image_na.jpg'
    bad_data = misc.imread(not_available_image_path)
    bad_data = misc.imresize(bad_data, [160,160])
    faulty_img = 0
    for num, path in enumerate(image_path):
        try:
            data = misc.imread(path)
#             print(data.shape)
            data = misc.imresize(data, [160,160])
            if data.shape[2] != 3:                     #  Somtimes the image comes with 4 channels
                faulty_img += 1
                b = "TOTAL Faulty Images Found ======== %s"
                print (b%(faulty_img), end="\r")
                os.remove(path)
            elif (bad_data == data).all():
                faulty_img += 1
                b = "TOTAL Faulty Images Found ======== %s"
                print (b%(faulty_img), end="\r")
                os.remove(path)
            else:
                pass
        except OSError:
            print ('Opps cant read the file: %s',os.path.basename(path))
            
if rmv_bad_streetside_images:
#     remove_not_available_data(streetside_land_dump_path)
    remove_not_available_data(streetside_house_dump_path)
# Out:
# TOTAL Faulty Images Found ======== 1282

# %% [markdown]
# # Step 6: Load Aerial Images (Google Static Maps):
# ------------

# %% [markdown]
# ### Gather Data Already Processed: (Due to exceed in daily quota google blocks web calls. Hence here we collate data that we have already gathered before to avoid redundancy)

# %%
google_aerial_stats_path = pathDict['google_aerial_stats_path']
google_aerial_stats = collateData(filesPath=google_aerial_stats_path, fileType="csv")
print (google_aerial_stats.shape)
google_aerial_stats.head()
# Out:
# (23313, 9)
#                   pin             address                    city        lat  \
# 0  17-10-104-037-1155       30 E HURON ST  CHICAGO                 41.895107
# 1  32-20-408-025-0000      1529 THORN ST         CHICAGO HEIGHTS   41.503230
# 2  17-20-200-092-4024  1075W ROOSEVELT RD                 CHICAGO  41.866766
# 3  20-17-118-015-0000    5737 S LAFLIN ST  CHICAGO                 41.789331
# 4  17-07-102-009-0000   2137W CHICAGO AVE                 CHICAGO  41.895638
#
#          lon            loc_type     indicator  \
# 0 -87.626584             ROOFTOP  Likely House
# 1 -87.643405             ROOFTOP   Likely Land
# 2 -87.653944  RANGE_INTERPOLATED  Likely House
# 3 -87.661754             ROOFTOP  Likely House
# 4 -87.680985             ROOFTOP  Likely House
#
#                                             meta_url  \
# 0  https://maps.googleapis.com/maps/api/geocode/j...
# 1  https://maps.googleapis.com/maps/api/geocode/j...
# 2  https://maps.googleapis.com/maps/api/geocode/j...
# 3  https://maps.googleapis.com/maps/api/geocode/j...
# 4  https://maps.googleapis.com/maps/api/geocode/j...
#
#                                              img_url
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...

# %%
processed_images = google_aerial_stats.dropna()
processed_images = processed_images[processed_images['meta_url'] != 'EXCEED']
print (processed_images.shape)
processed_images.head()
# Out:
# (23313, 9)
#                   pin             address                    city        lat  \
# 0  17-10-104-037-1155       30 E HURON ST  CHICAGO                 41.895107
# 1  32-20-408-025-0000      1529 THORN ST         CHICAGO HEIGHTS   41.503230
# 2  17-20-200-092-4024  1075W ROOSEVELT RD                 CHICAGO  41.866766
# 3  20-17-118-015-0000    5737 S LAFLIN ST  CHICAGO                 41.789331
# 4  17-07-102-009-0000   2137W CHICAGO AVE                 CHICAGO  41.895638
#
#          lon            loc_type     indicator  \
# 0 -87.626584             ROOFTOP  Likely House
# 1 -87.643405             ROOFTOP   Likely Land
# 2 -87.653944  RANGE_INTERPOLATED  Likely House
# 3 -87.661754             ROOFTOP  Likely House
# 4 -87.680985             ROOFTOP  Likely House
#
#                                             meta_url  \
# 0  https://maps.googleapis.com/maps/api/geocode/j...
# 1  https://maps.googleapis.com/maps/api/geocode/j...
# 2  https://maps.googleapis.com/maps/api/geocode/j...
# 3  https://maps.googleapis.com/maps/api/geocode/j...
# 4  https://maps.googleapis.com/maps/api/geocode/j...
#
#                                              img_url
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...

# %% [markdown]
# ### Empty the Directory and store only the processed data in batches:

# %%
import shutil
SURE = input("Sure? Delete all files from  %s "%(str(google_aerial_stats_path)))
shutil.rmtree(google_aerial_stats_path + '/')
os.makedirs(google_aerial_stats_path)
# Out:
# Sure? Delete all files from  /Users/sam/All-Program/App-DataSet/HouseClassification/statistics/aerial_images/google sure

# %%
processed_images = processed_images[['pin', 'address', 'city', 'lat', 'lon','loc_type', 'indicator', 'meta_url', 'img_url']]
processed_images.to_csv(os.path.join(google_aerial_stats_path, '%s_%s.csv'%(str(0), str(len(processed_images)-1))), index=None)

# %% [markdown]
# ### Aerial Land and House DUMP (Google)

# %%
land_house_data = pd.concat([land_data, house_data])
print (land_house_data.shape)
pd.concat([land_house_data.head(2), land_house_data.tail(2)])
# Out:
# (28265, 18)
#         row_id  removed  property_id state county_name                 pin  \
# 8746      8746        0       509513    IL        Cook  10-25-300-045-0000
# 9339      9339        0       510240    IL        Cook  10-31-417-045-0000
# 223392  223392        0      1426092    IL        Cook  17-30-105-004-0000
# 223393  223393        0      1426093    IL        Cook  17-30-112-038-0000
#
#             address_line1 address_line2 address_city  address_zip  \
# 8746    3125 W HOWARD ST            nan     CHICAGO   606451139.0
# 9339    6546 W DEVON AVE            nan     CHICAGO   606312038.0
# 223392      2051 W CERMAK           nan      CHICAGO        60608
# 223393        2337 W 23RD           nan      CHICAGO        60608
#
#              zoning improvement_level type exterior last_reviewed_timestamp  \
# 8746         Vacant              Land  nan      nan 2017-06-09 22:51:31.103
# 9339         Vacant              Land  nan      nan 2017-06-22 18:07:04.937
# 223392  Residential         Mixed Use  nan      nan 2017-06-23 15:07:43.277
# 223393  Residential          Improved  nan      nan 2017-06-23 15:07:43.277
#
#        gone_timestamp     indicator  \
# 8746              NaT   Likely Land
# 9339              NaT   Likely Land
# 223392            NaT  Likely House
# 223393            NaT  Likely House
#
#                                            assessor_photo
# 8746    http://www.cookcountyassessor.com/PropertyImag...
# 9339    http://www.cookcountyassessor.com/PropertyImag...
# 223392  http://www.cookcountyassessor.com/PropertyImag...
# 223393  http://www.cookcountyassessor.com/PropertyImag...

# %% [markdown]
# ### Remove from the land_house_data where the PIN is already processed

# %%
land_house_data = land_house_data[~land_house_data['pin'].isin(np.array(processed_images['pin'], dtype=str))]
print (land_house_data.shape)
land_house_data.head()
# Out:
# (13301, 18)
#        row_id  removed  property_id state county_name                 pin  \
# 13945   13945        0       515364    IL        Cook  12-24-219-042-0000
# 16124   16124        0       517888    IL        Cook  13-03-116-011-0000
# 16557   16557        0       518409    IL        Cook  13-07-132-022-0000
# 17190   17190        0       519165    IL        Cook  13-11-304-024-0000
# 17224   17224        0       519199    IL        Cook  13-11-312-042-0000
#
#                 address_line1 address_line2 address_city  address_zip  \
# 13945     3714 N OSCEOLA AVE            nan     CHICAGO   606343306.0
# 16124   6107N FOREST GLEN AVE           nan      CHICAGO      60646.0
# 16557      6905W FARRAGUT AVE           nan      CHICAGO      60656.0
# 17190    5101N MONTICELLO AVE           nan      CHICAGO      60625.0
# 17224  5051 N MONTICELLO AVE            nan     CHICAGO   606255521.0
#
#             zoning improvement_level type exterior last_reviewed_timestamp  \
# 13945  Residential              Land  nan      nan 2017-02-10 22:04:53.280
# 16124  Residential              Land  nan      nan 2017-02-10 22:04:53.280
# 16557       Vacant              Land  nan      nan 2017-02-10 22:04:53.280
# 17190  Residential              Land  nan      nan 2017-02-10 22:04:53.280
# 17224       Vacant              Land  nan      nan 2017-02-10 22:04:53.280
#
#       gone_timestamp    indicator  \
# 13945            NaT  Likely Land
# 16124            NaT  Likely Land
# 16557            NaT  Likely Land
# 17190            NaT  Likely Land
# 17224            NaT  Likely Land
#
#                                           assessor_photo
# 13945  http://www.cookcountyassessor.com/PropertyImag...
# 16124  http://www.cookcountyassessor.com/PropertyImag...
# 16557  http://www.cookcountyassessor.com/PropertyImag...
# 17190  http://www.cookcountyassessor.com/PropertyImag...
# 17224  http://www.cookcountyassessor.com/PropertyImag...

# %% [markdown]
# #### Shuffle

# %%
from sklearn.utils import shuffle
land_house_data = shuffle(land_house_data)
print (land_house_data.shape)
land_house_data.head()
# Out:
# (13301, 18)
#         row_id  removed  property_id state county_name                 pin  \
# 189785  189785        0       924917    IL        Cook  25-16-415-002-0000
# 179051  179051        0       913144    IL        Cook  25-19-217-003-0000
# 109984  109984        0       623634    IL        Cook  25-05-411-026-0000
# 196714  196714        0       964085    IL        Cook  13-24-211-010-0000
# 220759  220759        0      1215627    IL        Cook  17-16-238-028-2238
#
#                address_line1 address_line2            address_city  \
# 189785       351 W 109TH ST            nan                CHICAGO
# 179051    11307 S CHURCH ST            nan                CHICAGO
# 109984  9218 S. GREEN STREET           nan                 CHICAGO
# 196714    2431 W BRADLEY PL            nan                CHICAGO
# 220759    235 W VAN BUREN ST          P-13  CHICAGO
#
#         address_zip       zoning improvement_level           type  \
# 189785  606283309.0  Residential          Improved            nan
# 179051  606434223.0  Residential          Improved            nan
# 109984      60620.0  Residential          Improved  Single Family
# 196714        60618  Residential          Improved  Single Family
# 220759        60607  Residential       Condominium        Parking
#
#            exterior last_reviewed_timestamp gone_timestamp     indicator  \
# 189785          nan 2017-06-09 22:51:31.103            NaT  Likely House
# 179051          nan 2017-02-21 22:05:39.083            NaT  Likely House
# 109984        Brick 2017-02-10 21:21:30.520            NaT  Likely House
# 196714  Brick/Frame 2017-02-10 21:21:30.520            NaT  Likely House
# 220759          nan 2017-03-14 20:13:34.633            NaT  Likely House
#
#                                            assessor_photo
# 189785  http://www.cookcountyassessor.com/PropertyImag...
# 179051  http://www.cookcountyassessor.com/PropertyImag...
# 109984  http://www.cookcountyassessor.com/PropertyImag...
# 196714  http://www.cookcountyassessor.com/PropertyImag...
# 220759  http://www.cookcountyassessor.com/PropertyImag...

# %%
if dump_aerial_google_images:
    google_aerial.fetch_google_aerial_images(land_house_data, batch_size=100, get_stats=True)

# %% [markdown]
# # Step 7: Here we randomly select a subset of the images, the conditions for selection are:
#
# * Fisrst we run "get_valid_land_house_ids" under the main.py module to get images that were properly fetched for all different types of property images i.e "assessor", 'streetside', 'bing_aerial'.
# * Now that we have Google Aerial Images metadata, we perform the below operation to do some supposedly "bad data" removal
#     * A image should have a valid address_line1 and city. The address should not start with '0 0 GROVE AVE', '0 SUMMIT ST', '0 VACANT PROPERTY'
#     * The location_type should not be "RANGE_INTERPOLATED"
#     * The Lat and Lon should have a 4 or more than 4 decimal precision.

# %%
from main import get_valid_land_house_ids

valid_land_pins, valid_house_pins = get_valid_land_house_ids(images_per_label=None)
print ('Total qualifies valid pins each Label: ', len(valid_land_pins), len(valid_house_pins))
# Out:
# Total qualifies valid pins each Label:  6670 6670

# %%
google_stats_data = collateData(pathDict['google_aerial_stats_path'])
print (google_stats_data.shape)
google_stats_data.head()
# Out:
# (23313, 9)
#                   pin             address                    city        lat  \
# 0  17-10-104-037-1155       30 E HURON ST  CHICAGO                 41.895107
# 1  32-20-408-025-0000      1529 THORN ST         CHICAGO HEIGHTS   41.503230
# 2  17-20-200-092-4024  1075W ROOSEVELT RD                 CHICAGO  41.866766
# 3  20-17-118-015-0000    5737 S LAFLIN ST  CHICAGO                 41.789331
# 4  17-07-102-009-0000   2137W CHICAGO AVE                 CHICAGO  41.895638
#
#          lon            loc_type     indicator  \
# 0 -87.626584             ROOFTOP  Likely House
# 1 -87.643405             ROOFTOP   Likely Land
# 2 -87.653944  RANGE_INTERPOLATED  Likely House
# 3 -87.661754             ROOFTOP  Likely House
# 4 -87.680985             ROOFTOP  Likely House
#
#                                             meta_url  \
# 0  https://maps.googleapis.com/maps/api/geocode/j...
# 1  https://maps.googleapis.com/maps/api/geocode/j...
# 2  https://maps.googleapis.com/maps/api/geocode/j...
# 3  https://maps.googleapis.com/maps/api/geocode/j...
# 4  https://maps.googleapis.com/maps/api/geocode/j...
#
#                                              img_url
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...

# %% [markdown]
# ### Get Google API Data filtered with conditions mentioned above

# %%
data_to_model = google_stats_data[(google_stats_data['loc_type'] != 'RANGE_INTERPOLATED') & (google_stats_data['city'].str.lower().str.strip().str.match('chicago')) & (~google_stats_data['address'].str.lower().str.strip().str.match('0'))]
print (data_to_model.shape)
data_to_model.head()
# Out:
# (14607, 9)
#                   pin            address                    city        lat  \
# 0  17-10-104-037-1155      30 E HURON ST  CHICAGO                 41.895107
# 1  32-20-408-025-0000     1529 THORN ST         CHICAGO HEIGHTS   41.503230
# 3  20-17-118-015-0000   5737 S LAFLIN ST  CHICAGO                 41.789331
# 4  17-07-102-009-0000  2137W CHICAGO AVE                 CHICAGO  41.895638
# 5  20-19-332-031-0000  7030 S OAKLEY AVE                 CHICAGO  41.765589
#
#          lon loc_type     indicator  \
# 0 -87.626584  ROOFTOP  Likely House
# 1 -87.643405  ROOFTOP   Likely Land
# 3 -87.661754  ROOFTOP  Likely House
# 4 -87.680985  ROOFTOP  Likely House
# 5 -87.681006  ROOFTOP  Likely House
#
#                                             meta_url  \
# 0  https://maps.googleapis.com/maps/api/geocode/j...
# 1  https://maps.googleapis.com/maps/api/geocode/j...
# 3  https://maps.googleapis.com/maps/api/geocode/j...
# 4  https://maps.googleapis.com/maps/api/geocode/j...
# 5  https://maps.googleapis.com/maps/api/geocode/j...
#
#                                              img_url
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...
# 5  https://maps.googleapis.com/maps/api/staticmap...

# %%
data_to_model[data_to_model['indicator'] == 'Likely House'].shape
# Out:
# (8032, 9)

# %%
data_to_model[data_to_model['indicator'] == 'Likely Land'].shape
# Out:
# (6575, 9)

# %% [markdown]
# ### Create new images where the building footprints are overlayed on the google static map

# %%
# We have created the seven folder containing the shape files (using ism_bbox_jsonToshp.py module), related to Lat-Lon scoop. We store the folder names such as:
# Why we do this: Because the shape files are very big in size and performing read operation for each record would not be feasible. Hence we would like to 
# arrange the lat lon in such a way that we select all records belonging to a particular Lat-Lon and read the shp file from disk and process all the records.
bbox_shape_folder_path = '/Users/sam/All-Program/App-DataSet/HouseClassification/shape_files/building_bbox/'
scoop_arr = ['scoop_738_768', 'scoop_768_798', 'scoop_798_848', 'scoop_848_908', 'scoop_908_938', 'scoop_938_968', 'scoop_968_028']

lat_scoop = dict(scoop_738_768 = '41.738, -87.803, 41.768, -87.510',
                scoop_768_798 = '41.768, -87.803, 41.798, -87.510',
                scoop_798_848 = '41.798, -87.803, 41.848, -87.510',
                scoop_848_908 = '41.848, -87.803, 41.908, -87.510',
                scoop_908_938 = '41.908, -87.803, 41.938, -87.510',
                scoop_938_968 = '41.938, -87.803, 41.968, -87.510',
                scoop_968_028 = '41.968, -87.803, 42.028, -87.510')

# %%
from semantic_segmentation import utils as utl
from semantic_segmentation.latlon_to_pixelXY import get_image_corner_latlon_and_pxls_vals
import shapely.geometry as geom
import geopandas as gpd
zoom = 19


def image_corner_polygon_wraper(lat, lon, zoom):
    pxls_corner_arr, lonlat_corner_arr = get_image_corner_latlon_and_pxls_vals(lat, lon, zoom)
    tl_ll, tr_ll, bl_ll, br_ll = lonlat_corner_arr
    tl_pxl, tr_pxl, bl_pxl, br_pxl = pxls_corner_arr
    image_corner_polygon = geom.Polygon(np.array([tl_ll, tr_ll, br_ll, bl_ll, tl_ll]))
    return image_corner_polygon

def get_search_polygons(df, scoop_latlon):
    query = ''
    for num, (i, j) in enumerate(scoop_latlon):
        query += '((lon_scoop=="%s") & (lat_scoop=="%s"))'%(str(i),(j))
        if num!=(len(scoop_latlon)-1):
            query += ' | '
    return df[df.eval(query)]

def get_parcels_inside_image(df, image_polygon):
    list_parcel_ids = []
    for parcel_id, lon_cent, lat_cent in np.array(df[['parcel_id','lon_center', 'lat_center']]):
        lon_cent = float(lon_cent) 
        lat_cent = float(lat_cent)
        is_contains = image_polygon.contains(geom.Point([lon_cent, lat_cent]))
        if is_contains:
#             print (parcel_id)
            list_parcel_ids.append(parcel_id)
            
    if len(list_parcel_ids) > 0:
        return df[df['parcel_id'].isin(list_parcel_ids)]

count = 0
for scoop in scoop_arr:
    min_lat, max_lon, max_lat, min_lon = [float(i.strip()) for i in lat_scoop[scoop].split(',')]
    print (min_lat, max_lon, max_lat, min_lon)
    data_ = data_to_model[(data_to_model['lat'] >= min_lat) & (data_to_model['lat'] < max_lat) & (data_to_model['lon'] >= max_lon) & (data_to_model['lon'] < min_lon)]
    property_parcel = gpd.read_file(os.path.join(bbox_shape_folder_path, lat_scoop[scoop]))
    print (property_parcel.shape)
    
    for rcnt, (pin, lat, lon, label) in enumerate(np.array(data_[['pin', 'lat', 'lon', 'indicator']])):
        lat = float(lat)
        lon = float(lon)
        image_polygon = image_corner_polygon_wraper(lat, lon, zoom)
        print (image_polygon)
        
        scoop_lon, scooop_lat = utl.getscoopLonLat(lonIN=lon, latIN=lat, decimalPlaces=1000)
        scoop_latlon = utl.getscoopSearchItems(scoopLon=scoop_lon, scoopLat=scooop_lat, decimalPlaces=1000)
        
        search_polygons = get_search_polygons(property_parcel, scoop_latlon)
        print (search_polygons.shape)

        parcels_in_image = get_parcels_inside_image(search_polygons, image_polygon)
        print (parcels_in_image.shape)
        
        if rcnt == 5:
            break
    break
# Out:
# 41.738 -87.803 41.768 -87.51
# (93246, 13)
# POLYGON ((-87.68154204180294 41.76598911791236, -87.68046915819698 41.76598911791236, -87.68046915819698 41.76518887959237, -87.68154204180294 41.76518887959237, -87.68154204180294 41.76598911791236))
# (163, 13)
# (20, 13)
# POLYGON ((-87.67288524180297 41.75599408023912, -87.67181235819702 41.75599408023912, -87.67181235819702 41.75519371726574, -87.67288524180297 41.75519371726574, -87.67288524180297 41.75599408023912))
# (243, 13)
# (21, 13)
# POLYGON ((-87.57030374180297 41.7617645442573, -87.56923085819703 41.7617645442573, -87.56923085819703 41.76096425324744, -87.57030374180297 41.76096425324744, -87.57030374180297 41.7617645442573))
# (92, 13)
# (20, 13)
# POLYGON ((-87.67368344180296 41.76420312905027, -87.67261055819701 41.76420312905027, -87.67261055819701 41.76340286845449, -87.67368344180296 41.76340286845449, -87.67368344180296 41.76420312905027))
# (241, 13)
# (14, 13)
# POLYGON ((-87.55061924180298 41.74593104297755, -87.54954635819702 41.74593104297755, -87.54954635819702 41.74513055452732, -87.55061924180298 41.74513055452732, -87.55061924180298 41.74593104297755))
# (165, 13)
# (25, 13)
# POLYGON ((-87.61417974180294 41.7626036390248, -87.61310685819699 41.7626036390248, -87.61310685819699 41.76180335847997, -87.61417974180294 41.76180335847997, -87.61417974180294 41.7626036390248))
# (284, 13)
# (20, 13)
