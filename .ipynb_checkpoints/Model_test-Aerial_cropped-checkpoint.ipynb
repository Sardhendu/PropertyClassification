# %%
from __future__ import division, print_function, absolute_import
import logging
import time
import tensorflow as tf
import os
tf.logging.set_verbosity(tf.logging.ERROR)
import numpy as np
from config import pathDict
from conv_net.train import Train
from conv_net.test import Test
from data_transformation.data_prep import get_intersecting_images_pin, DumpBatches
from plot import Plot
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")


which_net = 'resnet'
batch_prepare = True
train = True
test = True
# Out:
# INPUT the RUN NAME: Options : ("A new run name" or "Any Previous Run Name"
#  WHICH_RUN = new_test
# INPUT: Image-type OPTIONS: (assessor, assessor_code, aerial, overlayed, aerial_cropped, streetside and ensemble
#  IMAGE_TYPE = aerial_cropped

# %%
# from clean_directories import clean
# clean(dict(overlayed='summary,batch'),which_vendor='google', which_model='resnet')

# %% [markdown]
# ## PREPARE/DUMP BATCHES:

# %%
start_time = time.time()

max_batches = None

if batch_prepare:
    start_time = time.time()
    
    cmn_land_pins, cmn_house_pins = get_intersecting_images_pin(is_assessor=False, is_aerial=False,
                                                                is_streetside=False, is_overlayed=False,
                                                                is_aerial_cropped=True, equal_proportion=True)
    print(len(cmn_land_pins), len(cmn_house_pins))
    
    tr_batch_size = 128
    ts_batch_size = (len(cmn_land_pins) + len(cmn_house_pins)) // 10
    cv_batch_size = (len(cmn_land_pins) + len(cmn_house_pins)) // 10
    
    params = dict(
            image_type='aerial_cropped',
            img_in_shape=[400, 400, 3],
            img_out_shape=[224, 224, 3],
            img_resize_shape=[128, 128, 3],
            img_crop_shape=[128, 128, 3],
            tr_batch_size = tr_batch_size,
            cv_batch_size = cv_batch_size,
            ts_batch_size = ts_batch_size,
            enable_rotation=True,
            shuffle_seed=881,
            get_stats=True,
            max_batches=max_batches)
    
    obj_cb = DumpBatches(params)
    obj_cb.dumpStratifiedBatches_balanced_class(cmn_land_pins, cmn_house_pins, is_cvalid_test=False)

print ('--------------- %s seconds ------------------'%(time.time() - start_time))
# Out:
# 937 937
# 1874 1874 1874 1874======== 13
# --------------- 89.04272866249084 seconds ------------------

# %% [markdown]
# ## TEST MODEL:

# %%
which_data = 'test'
tsoj = Test(params=dict(pprocessor_inp_img_shape=[224,224,3],
                        pprocessor_inp_crop_shape=[],
                        model_inp_img_shape=[224, 224, 3]),
                    device_type = 'gpu',
                    which_net='resnet')
fnl_tst_metric_stack = tsoj.run(use_checkpoint_for_run='sam_new',
                                use_checkpoint_for_imageType='aerial_cropped',
                                optional_batch_name=None,
                                which_checkpoint='all',
                                which_data=which_data,
                                dump_stats=True)
# Out:
# Test Graphs: RESNET
# Learning Rate: Initial:  0.0005
# Batch path C:\Users\newline\Documents\ImageClassification\data\batch_data\new_test\aerial_cropped, batch_names: ['train_0', 'train_1', 'train_10', 'train_11', 'train_12', 'train_13', 'train_2', 'train_3', 'train_4', 'train_5', 'train_6', 'train_7', 'train_8', 'train_9']
# Test Graphs: RESNET
# Learning Rate: Initial:  0.0005
# Batch path C:\Users\newline\Documents\ImageClassification\data\batch_data\new_test\aerial_cropped, batch_names: ['train_0', 'train_1', 'train_10', 'train_11', 'train_12', 'train_13', 'train_2', 'train_3', 'train_4', 'train_5', 'train_6', 'train_7', 'train_8', 'train_9']
# Test Graphs: RESNET
# Learning Rate: Initial:  0.0005
# Batch path C:\Users\newline\Documents\ImageClassification\data\batch_data\new_test\aerial_cropped, batch_names: ['train_0', 'train_1', 'train_10', 'train_11', 'train_12', 'train_13', 'train_2', 'train_3', 'train_4', 'train_5', 'train_6', 'train_7', 'train_8', 'train_9']
# Test Graphs: RESNET
# Learning Rate: Initial:  0.0005
# Batch path C:\Users\newline\Documents\ImageClassification\data\batch_data\new_test\aerial_cropped, batch_names: ['train_0', 'train_1', 'train_10', 'train_11', 'train_12', 'train_13', 'train_2', 'train_3', 'train_4', 'train_5', 'train_6', 'train_7', 'train_8', 'train_9']
# Test Graphs: RESNET
# Learning Rate: Initial:  0.0005
# Batch path C:\Users\newline\Documents\ImageClassification\data\batch_data\new_test\aerial_cropped, batch_names: ['train_0', 'train_1', 'train_10', 'train_11', 'train_12', 'train_13', 'train_2', 'train_3', 'train_4', 'train_5', 'train_6', 'train_7', 'train_8', 'train_9']

# %%
prediction_outcomes_path = os.path.join(pathDict['statistics_path'], 'prediction_stats', 'test_pred_outcomes.csv')
prediction_metrics_path = os.path.join(pathDict['statistics_path'], 'prediction_stats', 'test_pred_metrics.csv')
prediction_outcomes = pd.read_csv(prediction_outcomes_path)
prediction_metrics = pd.read_csv(prediction_metrics_path)
prediction_metrics.head()
# Out:
#           checkpoint test_batch  test_loss  test_acc  test_precsion  \
# 0  epoch_15_batch_70    train_0      0.103     0.961          0.968
# 1  epoch_15_batch_70    train_1      0.228     0.914          0.908
# 2  epoch_15_batch_70   train_10      0.136     0.953          0.968
# 3  epoch_15_batch_70   train_11      0.151     0.953          0.939
# 4  epoch_15_batch_70   train_12      0.242     0.906          0.906
#
#    test_recall
# 0        0.953
# 1        0.922
# 2        0.938
# 3        0.969
# 4        0.906

# %%
prediction_outcomes.head(3)
# Out:
#           checkpoint test_batch  true_label  pred_label  pred_prob
# 0  epoch_15_batch_70    train_0         0.0           0      1.000
# 1  epoch_15_batch_70    train_0         0.0           0      1.000
# 2  epoch_15_batch_70    train_0         0.0           0      0.999

# %%
np.unique(prediction_metrics["checkpoint"])
# Out:
# array(['epoch_15_batch_70', 'epoch_16_batch_59', 'epoch_16_batch_69',
#        'epoch_16_batch_70', 'epoch_17_batch_59'], dtype=object)

# %% [markdown]
# ## epoch_17_batch_59

# %%
from conv_net.utils import Score
predictions = prediction_outcomes[prediction_outcomes['checkpoint'] == 'epoch_17_batch_59']
accuracy = Score().accuracy(y_true=predictions["true_label"], y_pred=predictions["pred_label"])
precision = Score().precision(y_true=predictions["true_label"], y_pred=predictions["pred_label"], reverse=True)
recall = Score().recall(y_true=predictions["true_label"], y_pred=predictions["pred_label"], reverse=True)
auc = Score().auc(y_true=predictions["true_label"], y_pred=predictions["pred_label"])
print (accuracy, precision, recall, auc)
# Out:
# 0.932764140875 0.949058693245 0.91462113127 0.932764140875

# %%
# GET Precision, Recall and Accuracy for several Theshold
acc_arr, prscn_arr, rcall_arr, thresholds = Score().prec_rec_acc_for_thresh(
    y_true=np.array(predictions["true_label"]), y_pred=np.array(predictions["pred_label"]), 
    y_pred_prob=np.array(predictions["pred_prob"]), num_thres=100, reverse=False
)

# %%
from plot import Plot
obj_plt = Plot(1,2, (30,10))
obj_plt.vizualize(data=predictions[["true_label", "pred_label"]], 
                 colX="true_label", colY="pred_label", 
                 label_col=None, viz_type="pr_curve", 
                 params={"title":"Precision Recall Curve", 'reverse':True})
obj_plt.vizualize(data=pd.DataFrame({'threshold': thresholds, 'accuracy':acc_arr, 'precision':prscn_arr, 'recall':rcall_arr}), 
                 colX='threshold', colY=None, label_col=None, viz_type="line",
                  params={"title":"Accuracy VS Precision VS Recall", 'xlabel':"Threshold", "ylabel":"Metrics"})

# %% [markdown]
# ## epoch_16_batch_70

# %%
from conv_net.utils import Score
predictions = prediction_outcomes[prediction_outcomes['checkpoint'] == 'epoch_16_batch_70']
accuracy = Score().accuracy(y_true=predictions["true_label"], y_pred=predictions["pred_label"])
precision = Score().precision(y_true=predictions["true_label"], y_pred=predictions["pred_label"], reverse=True)
recall = Score().recall(y_true=predictions["true_label"], y_pred=predictions["pred_label"], reverse=True)
auc = Score().auc(y_true=predictions["true_label"], y_pred=predictions["pred_label"])
print (accuracy, precision, recall, auc)
# Out:
# 0.937033084312 0.93984962406 0.933831376734 0.937033084312

# %%
# GET Precision, Recall and Accuracy for several Theshold
acc_arr, prscn_arr, rcall_arr, thresholds = Score().prec_rec_acc_for_thresh(
    y_true=np.array(predictions["true_label"]), y_pred=np.array(predictions["pred_label"]), 
    y_pred_prob=np.array(predictions["pred_prob"]), num_thres=100, reverse=False
)

# %%
from plot import Plot
obj_plt = Plot(1,2, (30,10))
obj_plt.vizualize(data=predictions[["true_label", "pred_label"]], 
                 colX="true_label", colY="pred_label", 
                 label_col=None, viz_type="pr_curve", 
                 params={"title":"Precision Recall Curve", 'reverse':True})
obj_plt.vizualize(data=pd.DataFrame({'threshold': thresholds, 'accuracy':acc_arr, 'precision':prscn_arr, 'recall':rcall_arr}), 
                 colX='threshold', colY=None, label_col=None, viz_type="line",
                  params={"title":"Accuracy VS Precision VS Recall", 'xlabel':"Threshold", "ylabel":"Metrics"})

# %% [markdown]
# ## Best of: epoch_17_batch_59 and epoch_16_batch_70:
# * When both the probabilities are equal then the latest epoch is given more preference

# %%
predictions_17_59 = prediction_outcomes[prediction_outcomes['checkpoint'] == 'epoch_17_batch_59'][["test_batch","true_label", "pred_label", "pred_prob"]].reset_index().drop('index', axis=1)
predictions_17_59.columns = ["test_batch","true_label_1", "pred_label_1", "pred_prob_1"]
predictions_16_70 = prediction_outcomes[prediction_outcomes['checkpoint'] == 'epoch_16_batch_70'][["true_label", "pred_label", "pred_prob"]].reset_index().drop('index', axis=1)
predictions_16_70.columns = ["true_label_2", "pred_label_2", "pred_prob_2"]
combined_pred = pd.concat([predictions_17_59, predictions_16_70], axis=1)
combined_pred.head()
# Out:
#   test_batch  true_label_1  pred_label_1  pred_prob_1  true_label_2  \
# 0    train_0           0.0             0        1.000           0.0
# 1    train_0           0.0             0        1.000           0.0
# 2    train_0           0.0             0        0.999           0.0
# 3    train_0           0.0             0        1.000           0.0
# 4    train_0           0.0             0        1.000           0.0
#
#    pred_label_2  pred_prob_2
# 0             0          1.0
# 1             0          1.0
# 2             0          1.0
# 3             0          1.0
# 4             0          1.0

# %%
pred_17_59_better = combined_pred[combined_pred["pred_prob_1"] >= combined_pred["pred_prob_2"]][["test_batch", "true_label_1", "pred_label_1", "pred_prob_1"]]
pred_17_59_better.columns = ["test_batch", "true_label", "pred_label", "pred_prob"]
pred_17_59_better.head()
# Out:
#   test_batch  true_label  pred_label  pred_prob
# 0    train_0         0.0           0      1.000
# 1    train_0         0.0           0      1.000
# 3    train_0         0.0           0      1.000
# 4    train_0         0.0           0      1.000
# 5    train_0         0.0           1      0.684

# %%
pred_16_70_better = combined_pred[combined_pred["pred_prob_2"] > combined_pred["pred_prob_1"]][["test_batch", "true_label_2", "pred_label_2", "pred_prob_2"]]
pred_16_70_better.columns = ["test_batch", "true_label", "pred_label", "pred_prob"]
pred_16_70_better.head()
# Out:
#    test_batch  true_label  pred_label  pred_prob
# 2     train_0         0.0           0      1.000
# 6     train_0         0.0           0      0.887
# 7     train_0         0.0           0      1.000
# 10    train_0         0.0           0      0.998
# 17    train_0         0.0           0      1.000

# %%
predictions = pd.concat([pred_17_59_better, pred_16_70_better])
predictions.head()
# Out:
#   test_batch  true_label  pred_label  pred_prob
# 0    train_0         0.0           0      1.000
# 1    train_0         0.0           0      1.000
# 3    train_0         0.0           0      1.000
# 4    train_0         0.0           0      1.000
# 5    train_0         0.0           1      0.684

# %%
accuracy = Score().accuracy(y_true=predictions["true_label"], y_pred=predictions["pred_label"])
precision = Score().precision(y_true=predictions["true_label"], y_pred=predictions["pred_label"], reverse=True)
recall = Score().recall(y_true=predictions["true_label"], y_pred=predictions["pred_label"], reverse=True)
auc = Score().auc(y_true=predictions["true_label"], y_pred=predictions["pred_label"])
print (accuracy, precision, recall, auc)
# Out:
# 0.934898612593 0.944383860414 0.924226254002 0.934898612593

# %%
# GET Precision, Recall and Accuracy for several Theshold
acc_arr, prscn_arr, rcall_arr, thresholds = Score().prec_rec_acc_for_thresh(
    y_true=np.array(predictions["true_label"]), y_pred=np.array(predictions["pred_label"]), 
    y_pred_prob=np.array(predictions["pred_prob"]), num_thres=100, reverse=False
)

# %%
from plot import Plot
obj_plt = Plot(1,2, (30,10))
obj_plt.vizualize(data=predictions[["true_label", "pred_label"]], 
                 colX="true_label", colY="pred_label", 
                 label_col=None, viz_type="pr_curve", 
                 params={"title":"Precision Recall Curve", 'reverse':True})
obj_plt.vizualize(data=pd.DataFrame({'threshold': thresholds, 'accuracy':acc_arr, 'precision':prscn_arr, 'recall':rcall_arr}), 
                 colX='threshold', colY=None, label_col=None, viz_type="line",
                  params={"title":"Accuracy VS Precision VS Recall", 'xlabel':"Threshold", "ylabel":"Metrics"})
